# %%
df = spark.table("superstore")
display(df)

# %%
dbutils.widgets.dropdown("Time_period","Weekly",["Weekly","Monthly"])

# %%
from datetime import date,datetime,timedelta
from pyspark.sql.functions import *

time_period = dbutils.widgets.get("Time_period")
print(time_period)
today = date.today() - timedelta(days=2*365)

if time_period == "Weekly":
    start_date = today - timedelta(days=today.weekday(),weeks=1)-timedelta(days=1)
    end_date = start_date + timedelta(days=6)
    
else:
    first = today.replace(day=1)
    start_date = first-timedelta(days=end_date.day)
    end_date = first-timedelta(days=1)

print(start_date,"to",end_date)

# %%
df.createOrReplaceTempView("sample")
display(spark.sql("SELECT count(DISTINCT customer_id) FROM sample"))

# %%
display(spark.sql(f"""select count(distinct customer_id) from sample where order_date between '{start_date}' and '{end_date}' """))

# %%
display(spark.sql("SELECT count(DISTINCT order_id) FROM sample"))

# %%
display(spark.sql(f"""select count(distinct order_id) from sample where order_date between '{start_date}' and '{end_date}' """))

# %%
display(spark.sql("SELECT sum(sales),sum(profit) FROM sample"))

# %%
display(spark.sql("SELECT sum(sales),sum(profit),country FROM sample group by 3"))
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
display(spark.sql("SELECT round(sum(sales)) as sales,round(sum(profit)) as profit,country,region FROM sample GROUP BY 3,4 ORDER BY profit DESC"))
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
display(spark.sql("SELECT ROUND(sum(sales),2) as sales, ROUND(sum(profit),2) as profit, category FROM sample GROUP BY 3 ORDER BY profit DESC "))
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
display(spark.sql("SELECT ROUND(sum(sales),2) as sales, ROUND(sum(profit),2) as profit, sub_category FROM sample GROUP BY 3 ORDER BY profit DESC LIMIT 10"))
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
display(spark.sql("SELECT ROUND(sum(quantity),2) as quantity, Product_name FROM sample GROUP BY 2 ORDER BY quantity DESC LIMIT 10"))
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
display(spark.sql("SELECT ROUND(sum(sales),2) as sales, customer_name,city FROM sample GROUP BY 2,3 ORDER BY sales DESC LIMIT 10"))
# Out:
# Databricks visualization. Run in Databricks to view.
